# %% [markdown]
# # Run cell below to conduct analysis and predict price
# ##### Can type in upper or lowercase
# ##### Can select state or national data, and prediction type
# ##### Must run cell again to re-type inputs

# %%
from Step3_Analysis_and_Forecast import Energy_Price_Impact_Tool

# %%
Energy_Price_Impact_Tool()
# Out:
# Enter your abbreviated state name or US for national data: us
# Enter your consumer type, type R for Residential, C for Commercial, I for Industrial: r
# Enter your predictive factor type, P for Percentage of Energy Source mix, or G for Generation in MWh: p
# US    Residential  Core_CPI  Residential_adj  Renewables_pct  \
# Year
# 1994         8.38  100.0000             8.38           10.37
# 1995         8.40  103.0000             8.17           11.47
# 1996         8.36  105.6780             7.90           12.28
# 1997         8.43  108.0029             7.79           12.42
# 1998         8.26  110.5950             7.51           11.06
# 1999         8.16  112.6963             7.26           10.80
# 2000         8.24  115.6264             7.09            9.38
# 2001         8.62  118.7483             7.22            7.70
# 2002         8.52  121.0045             7.02            8.90
# 2003         9.17  122.3355             7.39            9.15
# ...
